# %%
import pandas as pd
import numpy as np

# %%
tract_outcomes_early = pd.read_csv("/Users/rishigummakonda/Desktop/tract_outcomes_early.csv")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (5703) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
tract_outcomes_early.shape
# Out:
# (73278, 7825)

# %%
for col in tract_outcomes_early.columns:
    print(col)
# Out:
# state
# county
# tract
# kir_natam_female_p1
# kir_natam_female_p25
# kir_natam_female_p50
# kir_natam_female_p75
# kir_natam_female_p100
# kir_natam_female_n
# kir_natam_female_mean
# jail_natam_female_p1
# jail_natam_female_p25
# jail_natam_female_p50
# jail_natam_female_p75
# jail_natam_female_p100
# jail_natam_female_n
# jail_natam_female_mean
# kfr_natam_female_p1
# kfr_natam_female_p25
# kfr_natam_female_p50
# kfr_natam_female_p75
# kfr_natam_female_p100
# kfr_natam_female_n
# kfr_natam_female_mean
# kfr_top20_natam_female_p1
# kfr_top20_natam_female_p25
# kfr_top20_natam_female_p50
# kfr_top20_natam_female_p75
# kfr_top20_natam_female_p100
# kfr_top20_natam_female_n
# kfr_top20_natam_female_mean
# kir_top20_natam_female_p1
# kir_top20_natam_female_p25
# kir_top20_natam_female_p50
# kir_top20_natam_female_p75
# kir_top20_natam_female_p100
# kir_top20_natam_female_n
# kir_top20_natam_female_mean
# married_natam_female_p1
# married_natam_female_p25
# married_natam_female_p50
# ...

# %%
kfr_pool_cols = [col for col in tract_outcomes_early.columns if "kfr_pool" in col]
print(list(kfr_pool_cols))
# Out:
# ['kfr_pooled_female_p1', 'kfr_pooled_female_p25', 'kfr_pooled_female_p50', 'kfr_pooled_female_p75', 'kfr_pooled_female_p100', 'kfr_pooled_female_n', 'kfr_pooled_female_mean', 'kfr_pooled_female_p10', 'kfr_pooled_male_p1', 'kfr_pooled_male_p25', 'kfr_pooled_male_p50', 'kfr_pooled_male_p75', 'kfr_pooled_male_p100', 'kfr_pooled_male_n', 'kfr_pooled_male_mean', 'kfr_pooled_male_p10', 'kfr_pooled_pooled_p1', 'kfr_pooled_pooled_p25', 'kfr_pooled_pooled_p50', 'kfr_pooled_pooled_p75', 'kfr_pooled_pooled_p100', 'kfr_pooled_pooled_n', 'kfr_pooled_pooled_mean', 'kfr_pooled_pooled_p10', 'kfr_pooled_female_p25_se', 'kfr_pooled_female_p75_se', 'kfr_pooled_male_p25_se', 'kfr_pooled_male_p75_se', 'kfr_pooled_pooled_p25_se', 'kfr_pooled_pooled_p75_se', 'kfr_pooled_female_mean_se', 'kfr_pooled_male_mean_se', 'kfr_pooled_pooled_mean_se']

# %%
print(len(list(kfr_pool_cols)))
# Out:
# 33
